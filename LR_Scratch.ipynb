# %% [markdown]
# <a href="https://colab.research.google.com/github/stva01/ML_from_scratch/blob/main/LR_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/train.csv')
df.head()
# Out:
#    id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0   0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4   I  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    Viscera Weight  Shell Weight  Age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %%
df=df[['Length','Weight']]
df.head()
# Out:
#    Length     Weight
# 0  1.5250  28.973189
# 1  1.1000  10.418441
# 2  1.3875  24.777463
# 3  1.7000  50.660556
# 4  1.2500  23.289114

# %%
plt.scatter(df.Length,df.Weight)
plt.xlabel('Length')
plt.ylabel('Weight')
plt.show()

# %%
#calculates the mse manually no need to use in actaul optimization as it is included in gradient descent
#we need to not only calc the loss but apply partial fraction to actaully minimize the loss

def loss_function(m,b,points):
  total_error=0
  for i in range (len(points)):
    x=iloc[i].Length
    y=iloc[i].Weight
    total_error+=(y-(m*x+b))**2
  total_error/float(len(points))

# %%
#gradient descent
def gradient_descent(m_now,b_now,points,Learning_rate):
  m_gradient=0
  b_gradient=0
  n=len(points)

  for i in range(n):
      x=points.iloc[i].Length
      y=points.iloc[i].Weight

      m_gradient+=(-2/n) * x * (y -(m_now * x + b_now))
      b_gradient+=(-2/n) *(y -(m_now * x + b_now))

  m=m_now-m_gradient*Learning_rate
  b=m_now-m_gradient*Learning_rate

  return m,b

# %%
m=0
b=0
Learning_rate=0.001
epochs=10000


for i in range (epochs) :
  m,b=gradient_descent(m,b,df,Learning_rate)
  if(i%500==0):
    print(f"epochs:{i}")

x_values=df['Length']
y_values = m * x_values+b


plt.scatter(df['Length'],df['Weight'])
plt.plot(x_values,y_values,color='red')
plt.plot()
# Out:
# epochs:0
